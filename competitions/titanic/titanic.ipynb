# %%
from typing import Tuple
from sklearn.model_selection import train_test_split

import pandas as pd

TRAIN_PATH = "kaggle/input/titanic/train.csv"
TEST_PATH = "kaggle/input/titanic/test.csv"
GENDER_SUBMISSION_PATH = "kaggle/input/titanic/gender_submission.csv"
RANDOM_STATE = 137

# %%
from typing import Union


def one_hot(df: pd.DataFrame, column_name: str) -> pd.DataFrame:
    df = df.copy()

    df[column_name] = list(map(lambda x: f'{column_name}_{x}', df[column_name]))
    one_hot = pd.get_dummies(df[column_name])
    df = df.drop(column_name, axis=1)
    df = df.join(one_hot)

    return df


def transform_name(names: pd.Series) -> pd.Series:
    return names

def print_nan_rows(df: pd.DataFrame) -> None:
    is_NaN = df.isnull()
    row_has_NaN = is_NaN.any(axis=1)
    rows_with_NaN = df[row_has_NaN]

    print(rows_with_NaN)

def drop_non_impormative_columns(data: pd.DataFrame) -> pd.DataFrame:
    return data.drop(columns=['Ticket', 'Name', 'Age', 'Cabin', 'Embarked', 'Fare'])

def transform_data(data: pd.DataFrame) -> pd.DataFrame:
    data = drop_non_impormative_columns(data)

    data = one_hot(data, 'Pclass')
    data = one_hot(data, 'Sex')
    data = one_hot(data, 'SibSp')
    data = one_hot(data, 'Parch')

    return data


def get_data_target(data: pd.DataFrame) -> Tuple[pd.DataFrame, Union[pd.Series, None]]:
    if 'Survived' in data.columns:
        target = data['Survived']
        return data.drop(columns=['Survived']), target
    else:
        return data, None

train = pd.read_csv(TRAIN_PATH).set_index('PassengerId')
test = pd.read_csv(TEST_PATH).set_index('PassengerId')

train = transform_data(train)
test = transform_data(test)

train_x, train_y = get_data_target(train)
test_x, _ = get_data_target(test)

for column in test_x.columns:
    if column not in train_x.columns:
        test_x.drop(columns=[column], inplace=True)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

parameters = {
    'n_estimators': [10, 100, 150, 250, 500],
    'max_depth': [1, 2, 3, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

clf = GridSearchCV(
    RandomForestClassifier(random_state=137),
    parameters,
    scoring=['accuracy'],
    refit='accuracy'
)
clf.fit(train_x, train_y)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(random_state=137),
#              param_grid={'max_depth': [1, 2, 3, 5, 10],
#                          'min_samples_leaf': [1, 2, 4],
#                          'n_estimators': [10, 100, 150, 250, 500]},
#              refit='accuracy', scoring=['accuracy'])

# %%
results = pd.DataFrame(clf.cv_results_)
results.sort_values(by=['rank_test_accuracy'], inplace=True, ascending=True)

for i in range(len(results['params'])):
    print(results['params'].iloc[i])
    print(results['mean_test_accuracy'].iloc[i])
# Out:
# {'max_depth': 5, 'min_samples_leaf': 4, 'n_estimators': 10}
# 0.8024794425961961
# {'max_depth': 3, 'min_samples_leaf': 1, 'n_estimators': 250}
# 0.8002134203753688
# {'max_depth': 5, 'min_samples_leaf': 2, 'n_estimators': 500}
# 0.7980164459230431
# {'max_depth': 3, 'min_samples_leaf': 4, 'n_estimators': 250}
# 0.7979599522942691
# {'max_depth': 5, 'min_samples_leaf': 2, 'n_estimators': 10}
# 0.796899127487289
# {'max_depth': 3, 'min_samples_leaf': 2, 'n_estimators': 250}
# 0.7968489109283786
# {'max_depth': 5, 'min_samples_leaf': 4, 'n_estimators': 500}
# 0.7957692549118072
# {'max_depth': 5, 'min_samples_leaf': 4, 'n_estimators': 250}
# 0.7957692549118072
# {'max_depth': 5, 'min_samples_leaf': 4, 'n_estimators': 150}
# 0.7957629778419433
# {'max_depth': 3, 'min_samples_leaf': 2, 'n_estimators': 10}
# 0.7957253154227607
# {'max_depth': 5, 'min_samples_leaf': 2, 'n_estimators': 100}
# 0.7946519364760529
# {'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# 0.7946519364760529
# {'max_depth': 10, 'min_samples_leaf': 2, 'n_estimators': 100}
# 0.7946456594061893
# {'max_depth': 10, 'min_samples_leaf': 2, 'n_estimators': 500}
# 0.7946456594061893
# {'max_depth': 3, 'min_samples_leaf': 1, 'n_estimators': 10}
# 0.7946017199171427
# {'max_depth': 3, 'min_samples_leaf': 2, 'n_estimators': 500}
# 0.7945954428472789
# {'max_depth': 3, 'min_samples_leaf': 2, 'n_estimators': 100}
# 0.7945954428472789
# {'max_depth': 3, 'min_samples_leaf': 1, 'n_estimators': 150}
# 0.7945954428472789
# {'max_depth': 3, 'min_samples_leaf': 4, 'n_estimators': 150}
# 0.7945891657774151
# {'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 250}
# 0.793528340970435
# {'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 150}
# 0.793528340970435
# {'max_depth': 5, 'min_samples_leaf': 2, 'n_estimators': 150}
# 0.793528340970435
# {'max_depth': 5, 'min_samples_leaf': 2, 'n_estimators': 250}
# 0.793528340970435
# {'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 500}
# 0.793528340970435
# {'max_depth': 10, 'min_samples_leaf': 2, 'n_estimators': 150}
# 0.7935220639005711
# {'max_depth': 10, 'min_samples_leaf': 2, 'n_estimators': 250}
# 0.7935220639005711
# {'max_depth': 10, 'min_samples_leaf': 4, 'n_estimators': 10}
# 0.7934969556211161
# {'max_depth': 3, 'min_samples_leaf': 2, 'n_estimators': 150}
# 0.7934781244115248
# {'max_depth': 3, 'min_samples_leaf': 1, 'n_estimators': 100}
# 0.7934718473416609
# {'max_depth': 3, 'min_samples_leaf': 1, 'n_estimators': 500}
# 0.7934718473416609
# {'max_depth': 3, 'min_samples_leaf': 4, 'n_estimators': 500}
# 0.7934655702717971
# {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 10}
# 0.7924110225346809
# {'max_depth': 5, 'min_samples_leaf': 4, 'n_estimators': 100}
# 0.7923984683949532
# {'max_depth': 10, 'min_samples_leaf': 4, 'n_estimators': 500}
# 0.7923984683949532
# {'max_depth': 3, 'min_samples_leaf': 4, 'n_estimators': 10}
# 0.7923545289059069
# {'max_depth': 10, 'min_samples_leaf': 2, 'n_estimators': 10}
# 0.7912811499591991
# {'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 10}
# 0.7912748728893353
# {'max_depth': 10, 'min_samples_leaf': 4, 'n_estimators': 250}
# 0.7912748728893353
# {'max_depth': 3, 'min_samples_leaf': 4, 'n_estimators': 100}
# 0.791224656330425
# {'max_depth': 10, 'min_samples_leaf': 4, 'n_estimators': 150}
# 0.7901512773837173
# {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 150}
# 0.7890339589479631
# {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 250}
# 0.7890339589479631
# {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 500}
# 0.7890339589479631
# {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 100}
# 0.7890339589479631
# {'max_depth': 10, 'min_samples_leaf': 4, 'n_estimators': 100}
# 0.7890276818780994
# {'max_depth': 2, 'min_samples_leaf': 1, 'n_estimators': 100}
# 0.7878664239532986
# {'max_depth': 2, 'min_samples_leaf': 4, 'n_estimators': 10}
# 0.7878601468834348
# {'max_depth': 2, 'min_samples_leaf': 1, 'n_estimators': 10}
# 0.7878601468834348
# {'max_depth': 2, 'min_samples_leaf': 2, 'n_estimators': 10}
# 0.7878601468834348
# {'max_depth': 2, 'min_samples_leaf': 1, 'n_estimators': 150}
# 0.7867428284476807
# {'max_depth': 1, 'min_samples_leaf': 1, 'n_estimators': 10}
# 0.7867365513778168
# {'max_depth': 2, 'min_samples_leaf': 2, 'n_estimators': 100}
# 0.7867365513778168
# {'max_depth': 1, 'min_samples_leaf': 2, 'n_estimators': 10}
# 0.7867365513778168
# {'max_depth': 2, 'min_samples_leaf': 2, 'n_estimators': 250}
# 0.7867365513778168
# {'max_depth': 2, 'min_samples_leaf': 4, 'n_estimators': 100}
# 0.7867365513778168
# {'max_depth': 1, 'min_samples_leaf': 4, 'n_estimators': 10}
# 0.7867365513778168
# {'max_depth': 2, 'min_samples_leaf': 1, 'n_estimators': 250}
# 0.7856192329420627
# {'max_depth': 2, 'min_samples_leaf': 4, 'n_estimators': 250}
# 0.7856129558721989
# {'max_depth': 2, 'min_samples_leaf': 2, 'n_estimators': 150}
# 0.7856129558721989
# {'max_depth': 2, 'min_samples_leaf': 4, 'n_estimators': 150}
# 0.7856129558721989
# {'max_depth': 2, 'min_samples_leaf': 4, 'n_estimators': 500}
# 0.7844956374364447
# {'max_depth': 2, 'min_samples_leaf': 2, 'n_estimators': 500}
# 0.7844956374364447
# {'max_depth': 2, 'min_samples_leaf': 1, 'n_estimators': 500}
# 0.7833783190006904
# {'max_depth': 1, 'min_samples_leaf': 2, 'n_estimators': 100}
# 0.7710752620676669
# {'max_depth': 1, 'min_samples_leaf': 4, 'n_estimators': 100}
# 0.7710752620676669
# {'max_depth': 1, 'min_samples_leaf': 1, 'n_estimators': 100}
# 0.7710752620676669
# {'max_depth': 1, 'min_samples_leaf': 1, 'n_estimators': 500}
# 0.7699516665620488
# {'max_depth': 1, 'min_samples_leaf': 2, 'n_estimators': 500}
# 0.7688280710564308
# {'max_depth': 1, 'min_samples_leaf': 2, 'n_estimators': 250}
# 0.7677044755508129
# {'max_depth': 1, 'min_samples_leaf': 4, 'n_estimators': 500}
# 0.7677044755508129
# {'max_depth': 1, 'min_samples_leaf': 4, 'n_estimators': 250}
# 0.7677044755508129
# {'max_depth': 1, 'min_samples_leaf': 1, 'n_estimators': 250}
# 0.7677044755508129
# {'max_depth': 1, 'min_samples_leaf': 1, 'n_estimators': 150}
# 0.766580880045195
# {'max_depth': 1, 'min_samples_leaf': 2, 'n_estimators': 150}
# 0.766580880045195
# {'max_depth': 1, 'min_samples_leaf': 4, 'n_estimators': 150}
# 0.766580880045195

# %%
from sklearn.metrics import accuracy_score

true = pd.read_csv(GENDER_SUBMISSION_PATH)['Survived'].to_numpy()
predict = clf.predict(test_x)

print(accuracy_score(true, predict))
# Out:
# 0.9569377990430622
